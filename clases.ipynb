# %%
print('Mi amigo dijo que "le fue bien en el examen"')
Arturo = 3.141592653589793
print(Arturo)

# %%
print("Escribe un número")
a = int(input())
print(a)
# Out:
# Escribe un número
# 2026

# %%
print("Escribe dos números") #Escribi la frase
a = int(input()) #Guarda un dato igual a
b = int(input()) #Guarda un dato igual b
print(a + b) #Imprime la suma de a y b
# Out:
# Escribe dos números
# 40
