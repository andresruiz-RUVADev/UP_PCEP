# %%
print("Por favor, escribe tu contraseña")
a = input()
print("Confirma tu contraseña")
b = input()
if a == b:
    print("las contraseñas coinciden")
else:
    print("Las contraseñas no coinciden")
# Out:
# Por favor, escribe tu contraseña
# Confirma tu contraseña
# las contraseñas coinciden

# %%
print("Escribe la base del triángulo")
b = float(input())
print("Escribe la altura")
h = float(input())
print("El área es", (b*h)/2, "cm^2")
# Out:
# Escribe la base del triángulo
# Escribe la altura
# El área es 67.0 cm^2

# %%
name = str(input())
n = int(input())
print (n * ("Hipp hipp hurra" + ", " + name + "! \n"))
# Out:
# Hipp hipp hurra, andres!
# Hipp hipp hurra, andres!
# Hipp hipp hurra, andres!
# Hipp hipp hurra, andres!
# Hipp hipp hurra, andres!
# Hipp hipp hurra, andres!
# Hipp hipp hurra, andres!
# Hipp hipp hurra, andres!
# Hipp hipp hurra, andres!
# Hipp hipp hurra, andres!
# Hipp hipp hurra, andres!
